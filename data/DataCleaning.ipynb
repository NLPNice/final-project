# %%
import pandas as pd
from lxml import etree, html

# %%
data= pd.read_csv('EP3600000.txt', sep='\t', header=None, names = ["PatenType", "PatentNumber", "PublicationType", "Date", "Language", "Part", "Number", "Contents"])

# %%
data.head()
# Out:
#   PatenType  PatentNumber PublicationType        Date Language   Part  Number  \
# 0        EP       3601685              A1  2020-02-05       de  TITLE       1
# 1        EP       3601685              A1  2020-02-05       en  TITLE       1
# 2        EP       3601685              A1  2020-02-05       fr  TITLE       1
# 3        EP       3600528              A1  2020-02-05       de  TITLE       1
# 4        EP       3600528              A1  2020-02-05       en  TITLE       1
#
#                                             Contents
# 0  VERFAHREN ZUR BESTIMMUNG VON OBJEKTPOSITIONSIN...
# 1  A METHOD FOR DETERMINING OBJECT POSITION INFOR...
# 2  PROCÉDÉ DE DÉTERMINATION D'INFORMATIONS DE POS...
# 3                  BIMODALES GEHÖRSTIMULATIONSSYSTEM
# 4                 BIMODAL HEARING STIMULATION SYSTEM

# %%
data = data.loc[data["Language"] == "en"]
data = data.loc[data["PublicationType"] == "B1"]

# %%
data.head()
# Out:
#        PatenType  PatentNumber PublicationType        Date Language   Part  \
# 151409        EP       3607095              B1  2020-03-25       en  TITLE
# 151411        EP       3607095              B1  2020-03-25       en  DESCR
# 151412        EP       3607095              B1  2020-03-25       en  CLAIM
# 151415        EP       3607095              B1  2020-03-25       en  PDFEP
# 181821        EP       3614486              B1  2020-04-08       en  TITLE
#
#         Number                                           Contents
# 151409       1  KIT AND METHOD FOR DETERMINING THE RECEPTIVITY...
# 151411       1  <!-- EPO <DP n="1"> --><heading id="h0001"><b>...
# 151412       1  <!-- EPO <DP n="34"> --><claim id="c-en-01-000...
# 151415       1  https://data.epo.org/publication-server/pdf-do...
# 181821       1             RADIO FREQUENCY (RF) CONDUCTIVE MEDIUM

# %%
data = data.loc[data["Part"] != "PDFEP"]

# %%
data = data.reset_index(drop=True)
data.head()
# Out:
#   PatenType  PatentNumber PublicationType        Date Language   Part  Number  \
# 0        EP       3607095              B1  2020-03-25       en  TITLE       1
# 1        EP       3607095              B1  2020-03-25       en  DESCR       1
# 2        EP       3607095              B1  2020-03-25       en  CLAIM       1
# 3        EP       3614486              B1  2020-04-08       en  TITLE       1
# 4        EP       3614486              B1  2020-04-08       en  DESCR       1
#
#                                             Contents
# 0  KIT AND METHOD FOR DETERMINING THE RECEPTIVITY...
# 1  <!-- EPO <DP n="1"> --><heading id="h0001"><b>...
# 2  <!-- EPO <DP n="34"> --><claim id="c-en-01-000...
# 3             RADIO FREQUENCY (RF) CONDUCTIVE MEDIUM
# 4  <!-- EPO <DP n="1"> --><heading id="h0001">BAC...

# %%
df_Descr = data[data["Part"] == "DESCR"].reset_index(drop=True)

# %%
descr_patents = df_Descr['PatentNumber'].unique()

# %%
descr_df = data[data['PatentNumber'].isin(descr_patents)]

# %%
df_Titles = descr_df[descr_df["Part"] == "TITLE"].reset_index(drop=True)
df_Claim = descr_df[descr_df["Part"] == "CLAIM"].reset_index(drop=True)

# %%
df_Titles
# Out:
#      PatenType  PatentNumber PublicationType        Date Language   Part  \
# 0           EP       3607095              B1  2020-03-25       en  TITLE
# 1           EP       3614486              B1  2020-04-08       en  TITLE
# 2           EP       3601957              B1  2020-04-15       en  TITLE
# 3           EP       3603117              B1  2020-04-29       en  TITLE
# 4           EP       3601435              B1  2020-04-29       en  TITLE
# ...        ...           ...             ...         ...      ...    ...
# 1191        EP       3618411              B1  2021-02-03       en  TITLE
# 1192        EP       3627901              B1  2021-02-03       en  TITLE
# 1193        EP       3656354              B1  2021-02-03       en  TITLE
# 1194        EP       3664341              B1  2021-02-03       en  TITLE
# 1195        EP       3672123              B1  2021-02-03       en  TITLE
#
#       Number                                           Contents
# 0          1  KIT AND METHOD FOR DETERMINING THE RECEPTIVITY...
# 1          1             RADIO FREQUENCY (RF) CONDUCTIVE MEDIUM
# 2          1                                     SENSOR PACKAGE
# 3          1  TOOLS FOR ARRANGING VOICE COIL LEADOUTS IN A M...
# 4          1  LIGHT SCATTERING POLYMERIC COMPOSITION WITH IM...
# ...      ...                                                ...
# 1191       1     MOBILE TERMINAL AND CONTROLLING METHOD THEREOF
# 1192       1  MANAGING CONNECTION RETRIES DUE TO ACCESS CLAS...
# 1193       1              DEVICE FOR ENDOVASCULAR AORTIC REPAIR
# 1194       1  METHOD FOR TRANSMITTING ACK/NACK IN WIRELESS C...
# 1195       1  ENCODING RATIO SETTING METHOD AND RADIO COMMUN...
#
# [1196 rows x 8 columns]

# %%
df_Descr.head()
# Out:
#   PatenType  PatentNumber PublicationType        Date Language   Part  Number  \
# 0        EP       3607095              B1  2020-03-25       en  DESCR       1
# 1        EP       3614486              B1  2020-04-08       en  DESCR       1
# 2        EP       3601957              B1  2020-04-15       en  DESCR       1
# 3        EP       3603117              B1  2020-04-29       en  DESCR       1
# 4        EP       3601435              B1  2020-04-29       en  DESCR       1
#
#                                             Contents
# 0  <!-- EPO <DP n="1"> --><heading id="h0001"><b>...
# 1  <!-- EPO <DP n="1"> --><heading id="h0001">BAC...
# 2  <!-- EPO <DP n="1"> --><heading id="h0001"><u>...
# 3  <!-- EPO <DP n="1"> --><heading id="h0001"><b>...
# 4  <!-- EPO <DP n="1"> --><heading id="h0001"><b>...

# %%
df_Claim.head()
# Out:
#   PatenType  PatentNumber PublicationType        Date Language   Part  Number  \
# 0        EP       3607095              B1  2020-03-25       en  CLAIM       1
# 1        EP       3614486              B1  2020-04-08       en  CLAIM       1
# 2        EP       3601957              B1  2020-04-15       en  CLAIM       1
# 3        EP       3603117              B1  2020-04-29       en  CLAIM       1
# 4        EP       3601435              B1  2020-04-29       en  CLAIM       1
#
#                                             Contents
# 0  <!-- EPO <DP n="34"> --><claim id="c-en-01-000...
# 1  <!-- EPO <DP n="8"> --><claim id="c-en-01-0001...
# 2  <!-- EPO <DP n="31"> --><claim id="c-en-01-000...
# 3  <!-- EPO <DP n="13"> --><claim id="c-en-01-000...
# 4  <!-- EPO <DP n="29"> --><claim id="c-en-01-000...

# %%
df_Claim.shape
# Out:
# (1196, 8)

# %%
def parse_desc(xml):
    description = html.fromstring(xml)
    
    
    sections = dict()
    headings = [e.tag == "heading" for e in description]
    if True in headings:
        description = description[headings.index(True):]
        # group all paragraphs from the same section
        i = 0
        section_i = 0
        cur_section = None
        while i < len(description):
          if description[i].tag == "heading":
            cur_section = description[i].text_content()
            sections[cur_section] = list()
          elif description[i].tag is not etree.Comment:
            sections[cur_section].append(description[i].text_content())
          i += 1
    else:
        sections['Heandingless description'] = description.text_content()

    return sections


df_Descr["Contents"] = df_Descr["Contents"].apply(parse_desc)

# %%
x["REFERENCE NUMERALS"]
# Out:
# ['',
#  '10storage compartment20closure element30first adhesive element31adhesive layer32cover layer33base layer34permanent adhesive35liner36landing zone40second adhesive element41release layer42base layer43permanent adhesive44liner45landing zone50container60supplemental product61cigarette paper booklet70hinge lid container71outer box72inner liner73elongated smoking articles74inlet75lid80can81top portion82base portion83screw closure90pouch91first wall92second wall93folding line94opening seam']

# %%
len(''.join(x["BRIEF DESCRIPTION OF DRAWINGS"]).split())
# Out:
# 85

# %%
def parse_claim(xml):
    tree = html.fromstring(xml)
    claims = tree.xpath("//claim")
    claims = [''.join(c.text_content()) for c in claims]
    return claims

df_Claim["Contents"] = df_Claim["Contents"].apply(parse_claim)

# %%
df_Claim.head()
# Out:
#   PatenType  PatentNumber PublicationType        Date Language   Part  Number  \
# 0        EP       3607095              B1  2020-03-25       en  CLAIM       1
# 1        EP       3614486              B1  2020-04-08       en  CLAIM       1
# 2        EP       3601957              B1  2020-04-15       en  CLAIM       1
# 3        EP       3603117              B1  2020-04-29       en  CLAIM       1
# 4        EP       3601435              B1  2020-04-29       en  CLAIM       1
#
#                                             Contents
# 0  [A kit for determining the receptivity status ...
# 1  [A radio frequency (RF) device comprising:a st...
# 2  [A sensor package, comprisinga sensor chip (3)...
# 3  [A tool for arranging voice coil leadouts in a...
# 4  [A polymeric composition, comprising:from 90.0...

# %%
df_Descr.head()
# Out:
#   PatenType  PatentNumber PublicationType        Date Language   Part  Number  \
# 0        EP       3607095              B1  2020-03-25       en  DESCR       1
# 1        EP       3614486              B1  2020-04-08       en  DESCR       1
# 2        EP       3601957              B1  2020-04-15       en  DESCR       1
# 3        EP       3603117              B1  2020-04-29       en  DESCR       1
# 4        EP       3601435              B1  2020-04-29       en  DESCR       1
#
#                                             Contents
# 0  {'FIELD OF THE INVENTION': ['The present inven...
# 1  {'BACKGROUND': ['Electromagnetic waves or elec...
# 2  {'Field of the Invention': ['The present inven...
# 3  {'RELATED APPLICATION': ['This application cla...
# 4  {'Field of the invention': ['The present inven...

# %%
import os

# %%
import glob

# %%
glob.glob
# Out:
# <function glob.glob(pathname, *, recursive=False)>
